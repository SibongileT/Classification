# %% [markdown]
# ## Notebook for models without the decades 1960 and 1970

# %%
import psycopg2 as pg
import pandas as pd


import matplotlib.pyplot as plt
import seaborn as sns
# %config InlineBackend.figure_formats = ['svg']
# %matplotlib inline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import accuracy_score
from sklearn.datasets import make_classification
from sklearn.metrics import classification_report,confusion_matrix,plot_confusion_matrix
from sklearn.metrics import roc_curve , roc_auc_score
from sklearn.model_selection import GridSearchCV
import pickle

#Import all the models that I will use
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier, VotingClassifier
import xgboost as xgb

# %%
connection_args = {
    'host': 'localhost', 
    'dbname': 'song_classifier',
}
connection = pg.connect(**connection_args)

# %%
query = "SELECT * FROM songs_of_the_80s\
        UNION\
        SELECT * FROM songs_of_the_90s\
        UNION\
        SELECT * FROM songs_of_the_00s\
        UNION\
        SELECT * FROM songs_of_the_10s;"

songs_df = pd.read_sql(query, connection)
songs_df.shape
# Out:
# (24698, 20)

# %% [markdown]
# * **In deleting the 1960s and 1970s I lost around 18000 rows of data but due to the lower scores of those decade and still having nearly 25000 records I will continue to work in this time frame**

# %%
# Checking to make sure the classes are still balanced
songs_df['target'].mean()
# Out:
# 0.5

# %%
sns.heatmap(songs_df.corr(), cmap="seismic", annot=True, vmin=-1, vmax=1);

# %%
X = songs_df.drop(columns=['target','uri','artist','track','decade'])
y = songs_df['target'].values

# %%
X_train,X_test,y_train,y_test = train_test_split(X, y,test_size=0.2)
X_train,X_val,y_train,y_val = train_test_split(X_train,y_train,test_size = 0.3)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

scaler.fit(X_train)

X_train_scaled = scaler.transform(X_train)
X_val_scaled = scaler.transform(X_val)
X_test_scaled = scaler.transform(X_test)

# %%
def get_metrics(X,y,X_val,y_val,model,name):
    model = model.fit(X,y)
    y_pred = model.predict(X_val)
    print('{} train score: {:.3f}'.format(name,model.score(X,y)))
    print('{} test score: {:.3f}'.format( name, model.score(X_val,y_val)))
    print(classification_report(y_val, y_pred))
    fig, ax = plt.subplots(figsize=(7, 7))
    print(plot_confusion_matrix(model, X_val, y_val, ax=ax,cmap=plt.cm.Greens))
    return model

def voting_classifier(model_list,voting):
    voting_classifier= VotingClassifier(estimators=model_list,
                                    voting=voting,
                                    n_jobs=-1)
    voting_classifier.fit(X_train_scaled, y_train)
    y_pred = voting_classifier.predict(X_val_scaled)
    print('Voting classifier val score: {:.3f}'.format(accuracy_score(y_val, y_pred)))
    print(classification_report(y_val, y_pred))
    fig, ax = plt.subplots(figsize=(7, 7))
    print(plot_confusion_matrix(voting_classifier, X_val_scaled, y_val, ax=ax,cmap=plt.cm.Greens))
    return voting_classifier

# %% [markdown]
# #### Running a grid search to find the best n

# %%
ks = list(range(1,51))

param_grid = dict(n_neighbors = ks)

nn = KNeighborsClassifier()

grid = GridSearchCV(nn, param_grid, cv = 5, scoring = 'accuracy',verbose=1)
grid.fit(X_train_scaled,y_train)
grid.best_params_
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 250 out of 250 | elapsed:  2.9min finished
# {'n_neighbors': 18}

# %% [markdown]
# * **Best n is 18**

# %%
knn = get_metrics(X_train_scaled,y_train,X_val_scaled,y_val,KNeighborsClassifier(n_neighbors=18,n_jobs=-1),'kNN')
# Out:
# kNN train score: 0.804
# kNN test score: 0.790
#               precision    recall  f1-score   support
#
#            0       0.86      0.68      0.76      2860
#            1       0.75      0.90      0.82      3068
#
#     accuracy                           0.79      5928
#    macro avg       0.80      0.79      0.79      5928
# weighted avg       0.80      0.79      0.79      5928
#
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x7fb0f7600eb0>

# %% [markdown]
# #### Logistic Regression

# %%
lr = get_metrics(X_train_scaled,y_train,X_val_scaled,y_val,LogisticRegression(penalty='none'),'lr')
# Out:
# lr train score: 0.778
# lr test score: 0.776
#               precision    recall  f1-score   support
#
#            0       0.81      0.70      0.75      2860
#            1       0.75      0.85      0.80      3068
#
#     accuracy                           0.78      5928
#    macro avg       0.78      0.77      0.77      5928
# weighted avg       0.78      0.78      0.77      5928
#
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x7fb0f6506ca0>

# %% [markdown]
# #### SVM

# %%
svc = get_metrics(X_train_scaled,y_train,X_val_scaled,y_val,SVC(probability=True),'svc')
# Out:
# svc train score: 0.830
# svc test score: 0.820
#               precision    recall  f1-score   support
#
#            0       0.87      0.74      0.80      2860
#            1       0.79      0.90      0.84      3068
#
#     accuracy                           0.82      5928
#    macro avg       0.83      0.82      0.82      5928
# weighted avg       0.83      0.82      0.82      5928
#
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x7fb0f8c2e6d0>

# %% [markdown]
# #### GaussianNB

# %%
nb = get_metrics(X_train_scaled,y_train,X_val_scaled,y_val,GaussianNB(),'nb')
# Out:
# nb train score: 0.740
# nb test score: 0.745
#               precision    recall  f1-score   support
#
#            0       0.83      0.59      0.69      2860
#            1       0.70      0.89      0.78      3068
#
#     accuracy                           0.75      5928
#    macro avg       0.77      0.74      0.74      5928
# weighted avg       0.76      0.75      0.74      5928
#
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x7fb0f7ccc9a0>

# %% [markdown]
# #### Decision Tree

# %%
dt = get_metrics(X_train_scaled,y_train,X_val_scaled,y_val,DecisionTreeClassifier(random_state=0),'dt')
# Out:
# dt train score: 1.000
# dt test score: 0.734
#               precision    recall  f1-score   support
#
#            0       0.72      0.75      0.73      2860
#            1       0.75      0.72      0.74      3068
#
#     accuracy                           0.73      5928
#    macro avg       0.73      0.73      0.73      5928
# weighted avg       0.74      0.73      0.73      5928
#
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x7fb0f8c2d1c0>

# %% [markdown]
# #### Decision Tree Grid Search

# %%
param_grid = {
    'max_depth': range(0,11),
    'min_samples_leaf': range(0,101),
}
dt =DecisionTreeClassifier()


grid_search = GridSearchCV(estimator = dt, param_grid = param_grid, 
                          cv = 3, n_jobs = -1, verbose = 2)

grid_search.fit(X_train_scaled, y_train)

grid_search.best_params_
# Out:
# Fitting 3 folds for each of 1111 candidates, totalling 3333 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=-1)]: Done 1072 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=-1)]: Done 1898 tasks      | elapsed:   15.2s
# [Parallel(n_jobs=-1)]: Done 2464 tasks      | elapsed:   23.2s
# [Parallel(n_jobs=-1)]: Done 3194 tasks      | elapsed:   36.2s
# [Parallel(n_jobs=-1)]: Done 3318 out of 3333 | elapsed:   38.3s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done 3333 out of 3333 | elapsed:   38.5s finished
# {'max_depth': 9, 'min_samples_leaf': 65}

# %%
dt = get_metrics(X_train_scaled,y_train,X_val_scaled,y_val,DecisionTreeClassifier(max_depth=9,min_samples_leaf=65),'dt')
# Out:
# dt train score: 0.812
# dt test score: 0.795
#               precision    recall  f1-score   support
#
#            0       0.80      0.77      0.78      2860
#            1       0.79      0.82      0.81      3068
#
#     accuracy                           0.80      5928
#    macro avg       0.80      0.79      0.79      5928
# weighted avg       0.80      0.80      0.80      5928
#
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x7fb0f7326fa0>

# %% [markdown]
# #### Random Forest

# %%
rf = get_metrics(X_train_scaled,y_train,X_val_scaled,y_val,RandomForestClassifier(random_state=0),'rf')
# Out:
# rf train score: 1.000
# rf test score: 0.825
#               precision    recall  f1-score   support
#
#            0       0.84      0.78      0.81      2860
#            1       0.81      0.87      0.84      3068
#
#     accuracy                           0.83      5928
#    macro avg       0.83      0.82      0.82      5928
# weighted avg       0.83      0.83      0.82      5928
#
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x7fb0f77083a0>

# %% [markdown]
# * Highly overfit will try a grid search to find best parameters

# %%
param_grid = {
    'max_depth': range(0,100),
    'min_samples_leaf': range(0,11),
}
rf = RandomForestClassifier()


grid_search = GridSearchCV(estimator = rf, param_grid = param_grid, 
                          cv = 3, n_jobs = -1, verbose = 2)

grid_search.fit(X_train_scaled, y_train)

grid_search.best_params_
# Out:
# Fitting 3 folds for each of 1100 candidates, totalling 3300 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=-1)]: Done 178 tasks      | elapsed:   18.8s
# [Parallel(n_jobs=-1)]: Done 381 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 664 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 1029 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=-1)]: Done 1474 tasks      | elapsed:  6.6min
# [Parallel(n_jobs=-1)]: Done 2001 tasks      | elapsed:  9.3min
# [Parallel(n_jobs=-1)]: Done 2608 tasks      | elapsed: 12.6min
# [Parallel(n_jobs=-1)]: Done 3300 out of 3300 | elapsed: 16.2min finished
# {'max_depth': 99, 'min_samples_leaf': 2}

# %%
rf = get_metrics(X_train_scaled,y_train,X_val_scaled,y_val,RandomForestClassifier(max_depth=99,min_samples_leaf=2),'rf')
# Out:
# rf train score: 0.989
# rf test score: 0.822
#               precision    recall  f1-score   support
#
#            0       0.84      0.77      0.81      2860
#            1       0.80      0.87      0.83      3068
#
#     accuracy                           0.82      5928
#    macro avg       0.82      0.82      0.82      5928
# weighted avg       0.82      0.82      0.82      5928
#
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x7fb0f86926a0>

# %% [markdown]
# * Still overfit will try to change min_samples_leaf

# %%
rf = get_metrics(X_train_scaled,y_train,X_val_scaled,y_val,RandomForestClassifier(max_depth=99,min_samples_leaf=9),'rf')
# Out:
# rf train score: 0.878
# rf test score: 0.823
#               precision    recall  f1-score   support
#
#            0       0.85      0.77      0.81      2860
#            1       0.80      0.87      0.84      3068
#
#     accuracy                           0.82      5928
#    macro avg       0.83      0.82      0.82      5928
# weighted avg       0.82      0.82      0.82      5928
#
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x7fb0f88c3a30>

# %% [markdown]
# * plot feature importance for random classifier

# %%
(pd.Series(rf.feature_importances_, index=X.columns)
   .nlargest(16)
   .plot(kind='barh')).invert_yaxis()

# %%
model_names = ["lr","nb","knn", "svc", "rf"]

model_vars = [eval(n) for n in model_names]
model_list = list(zip(model_names, model_vars))

# %%
for model_name in model_names:
    curr_model = eval(model_name)
    print(f'{model_name} score: {curr_model.score(X_val_scaled, y_val)}')
# Out:
# lr score: 0.7763157894736842
# nb score: 0.74527665317139
# knn score: 0.7904858299595142
# svc score: 0.8200067476383266
# rf score: 0.8227058029689609

# %% [markdown]
# ### Voting classifier w/ 'hard' voting

# %%
decision_voting = voting_classifier(model_list,'hard')
# Out:
# Voting classifier val score: 0.821
#               precision    recall  f1-score   support
#
#            0       0.87      0.76      0.81      2964
#            1       0.78      0.88      0.83      2964
#
#     accuracy                           0.82      5928
#    macro avg       0.83      0.82      0.82      5928
# weighted avg       0.83      0.82      0.82      5928
#
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x7fb0f768b490>

# %% [markdown]
# ### Voting classifier w/ 'soft' voting

# %%
avg_voting = voting_classifier(model_list,'soft')
# Out:
# Voting classifier val score: 0.811
#               precision    recall  f1-score   support
#
#            0       0.79      0.84      0.82      2964
#            1       0.83      0.78      0.81      2964
#
#     accuracy                           0.81      5928
#    macro avg       0.81      0.81      0.81      5928
# weighted avg       0.81      0.81      0.81      5928
#
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x7fb0f768b730>

# %% [markdown]
# ## Plot ROC

# %%
fpr_knn, tpr_knn, thresholds_knn = roc_curve(y_val, knn.predict_proba(X_val_scaled)[:,1])
fpr_log, tpr_log, thresholds_log = roc_curve(y_val, lr.predict_proba(X_val_scaled)[:,1])
fpr_nb, tpr_nb, thresholds_nb = roc_curve(y_val, nb.predict_proba(X_val_scaled)[:,1])
fpr_rf, tpr_rf, thresholds_rf = roc_curve(y_val, rf.predict_proba(X_val)[:,1])
fpr_svc, tpr_svc, thresholds_svc = roc_curve(y_val, svc.predict_proba(X_val_scaled)[:,1])
fpr_dt, tpr_dt, thresholds_dt = roc_curve(y_val, dt.predict_proba(X_val)[:,1])
fpr_vc,tpr_vc,thresholds_vc = roc_curve(y_val, avg_voting.predict_proba(X_val_scaled)[:,1])

# %%
plt.plot(fpr_knn, tpr_knn,lw=2)
plt.plot(fpr_log, tpr_log,lw=2)
plt.plot(fpr_nb, tpr_nb,lw=2)
plt.plot(fpr_rf, tpr_rf,lw=2)
plt.plot(fpr_svc, tpr_svc,lw=2)
plt.plot(fpr_dt, tpr_dt,lw=2)
plt.plot(fpr_vc, tpr_vc,lw=2)
plt.plot([0,1],[0,1],c='violet',ls='--')
plt.xlim([-0.05,1.05])
plt.ylim([-0.05,1.05])
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC Scores', fontweight='bold', fontsize=20);
plt.legend(['KNN', 'Logit', 'Naive Bayes', 'Random Forest','SVC', 'Decision Tree','Voting Classifier'])
print('KNN ROC AUC score = ', roc_auc_score(y_val, knn.predict_proba(X_val_scaled)[:,1]))
print('Logit ROC AUC score = ', roc_auc_score(y_val, lr.predict_proba(X_val_scaled)[:,1]))
print('Naive Bayes ROC AUC score = ', roc_auc_score(y_val, nb.predict_proba(X_val_scaled)[:,1]))
print('Random Forest ROC AUC score = ', roc_auc_score(y_val, rf.predict_proba(X_val_scaled)[:,1]))
print('Support Vector Machines ROC AUC score = ', roc_auc_score(y_val, svc.predict_proba(X_val_scaled)[:,1]))
print('Decision Tree ROC AUC score = ', roc_auc_score(y_val, dt.predict_proba(X_val_scaled)[:,1]))
print('Voting Classifier ROC AUC score = ', roc_auc_score(y_val, avg_voting.predict_proba(X_val_scaled)[:,1]))
# Out:
# KNN ROC AUC score =  0.8563400338253664
# Logit ROC AUC score =  0.8448433411438626
# Naive Bayes ROC AUC score =  0.8309627465103345
# Random Forest ROC AUC score =  0.8945383658062926
# Support Vector Machines ROC AUC score =  0.8864251784721147
# Decision Tree ROC AUC score =  0.8623421558884401
# Voting Classifier ROC AUC score =  0.883552529608592

# %% [markdown]
# ## Try Models with Top 100 Artist by Value Counts

# %% [markdown]
# * **First I'm gonna plot the top 20 artist and there hit/flop counts**

# %%
top_twenty = songs_df['artist'].value_counts().iloc[:21]
mask = songs_df['artist'].isin(top_twenty.index)

# %%
sns.countplot(songs_df['artist'][mask],hue=songs_df['target'],palette="Paired");
plt.xticks(rotation=90);
plt.savefig('artist.png')
# Out:
# /Users/sibongiletoure/anaconda3/envs/metis/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
top_hundred = songs_df['artist'].value_counts().iloc[:101]
mask = songs_df['artist'].isin(top_hundred.index)

# %%
artist_dummies = pd.get_dummies(songs_df['artist'][mask])
songs_df = pd.concat([songs_df, artist_dummies], axis=1)
songs_df.shape
# Out:
# (24698, 121)

# %%
X = songs_df.drop(columns=['target','uri','track','artist','decade'])
y = songs_df['target'].values

# %%
X.fillna(0,inplace=True)

# %%
X_train,X_test,y_train,y_test = train_test_split(X, y,test_size=0.2)
X_train,X_val,y_train,y_val = train_test_split(X_train,y_train,test_size = 0.3)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

scaler.fit(X_train)

# scaledfile = 'finalized_scale.sav'
# pickle.dump(scaler, open(scaledfile, 'wb'))

X_train_scaled = scaler.transform(X_train)
X_val_scaled = scaler.transform(X_val)
X_test_scaled = scaler.transform(X_test)

# %%
ks = list(range(1,51))

param_grid = dict(n_neighbors = ks)

nn = KNeighborsClassifier()

grid = GridSearchCV(nn, param_grid, cv = 5, scoring = 'accuracy',verbose=1)
grid.fit(X_train_scaled,y_train)
grid.best_params_
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 250 out of 250 | elapsed: 20.7min finished
# {'n_neighbors': 18}

# %%
knn = get_metrics(X_train_scaled,y_train,X_val_scaled,y_val,KNeighborsClassifier(n_neighbors=18,n_jobs=-1),'kNN')
# Out:
# kNN train score: 0.823
# kNN test score: 0.806
#               precision    recall  f1-score   support
#
#            0       0.88      0.71      0.78      2964
#            1       0.76      0.90      0.82      2964
#
#     accuracy                           0.81      5928
#    macro avg       0.82      0.81      0.80      5928
# weighted avg       0.82      0.81      0.80      5928
#
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x7fb0f72a5940>

# %%
lr = get_metrics(X_train_scaled,y_train,X_val_scaled,y_val,LogisticRegression(penalty='none'),'lr')
# Out:
# lr train score: 0.801
# lr test score: 0.797
#               precision    recall  f1-score   support
#
#            0       0.84      0.74      0.78      2964
#            1       0.77      0.86      0.81      2964
#
#     accuracy                           0.80      5928
#    macro avg       0.80      0.80      0.80      5928
# weighted avg       0.80      0.80      0.80      5928
#
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x7fb0f7204640>

# %%
svc = get_metrics(X_train_scaled,y_train,X_val_scaled,y_val,SVC(probability=True),'svc')
# Out:
# svc train score: 0.821
# svc test score: 0.817
#               precision    recall  f1-score   support
#
#            0       0.89      0.73      0.80      2964
#            1       0.77      0.91      0.83      2964
#
#     accuracy                           0.82      5928
#    macro avg       0.83      0.82      0.82      5928
# weighted avg       0.83      0.82      0.82      5928
#
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x7fb0f8c048b0>

# %%
nb = get_metrics(X_train_scaled,y_train,X_val_scaled,y_val,GaussianNB(),'nb')
# Out:
# nb train score: 0.559
# nb test score: 0.562
#               precision    recall  f1-score   support
#
#            0       0.53      1.00      0.70      2964
#            1       0.99      0.12      0.22      2964
#
#     accuracy                           0.56      5928
#    macro avg       0.76      0.56      0.46      5928
# weighted avg       0.76      0.56      0.46      5928
#
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x7fb0f82132b0>

# %%
dt = get_metrics(X_train_scaled,y_train,X_val_scaled,y_val,DecisionTreeClassifier(random_state=0),'dt')
# Out:
# dt train score: 0.999
# dt test score: 0.749
#               precision    recall  f1-score   support
#
#            0       0.75      0.76      0.75      2964
#            1       0.75      0.74      0.75      2964
#
#     accuracy                           0.75      5928
#    macro avg       0.75      0.75      0.75      5928
# weighted avg       0.75      0.75      0.75      5928
#
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x7fb0f746c1c0>

# %%
param_grid = {
    'max_depth': range(0,100),
    'min_samples_leaf': range(0,11),
}
rf = RandomForestClassifier()


grid_search = GridSearchCV(estimator = rf, param_grid = param_grid, 
                          cv = 3, n_jobs = -1, verbose = 2)

grid_search.fit(X_train_scaled, y_train)

grid_search.best_params_
# Out:
# Fitting 3 folds for each of 1100 candidates, totalling 3300 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed:   18.5s
# [Parallel(n_jobs=-1)]: Done 349 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 632 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 997 tasks      | elapsed:  4.6min
# [Parallel(n_jobs=-1)]: Done 1442 tasks      | elapsed:  7.2min
# [Parallel(n_jobs=-1)]: Done 1969 tasks      | elapsed:  9.9min
# [Parallel(n_jobs=-1)]: Done 2576 tasks      | elapsed: 12.2min
# [Parallel(n_jobs=-1)]: Done 3265 tasks      | elapsed: 15.1min
# [Parallel(n_jobs=-1)]: Done 3300 out of 3300 | elapsed: 15.2min finished
# {'max_depth': 46, 'min_samples_leaf': 1}

# %%
rf = get_metrics(X_train_scaled,y_train,X_val_scaled,y_val,RandomForestClassifier(random_state=0,max_depth=46,min_samples_leaf=1),'rf')
# Out:
# rf train score: 0.999
# rf test score: 0.826
#               precision    recall  f1-score   support
#
#            0       0.84      0.80      0.82      2964
#            1       0.81      0.85      0.83      2964
#
#     accuracy                           0.83      5928
#    macro avg       0.83      0.83      0.83      5928
# weighted avg       0.83      0.83      0.83      5928
#
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x7fb0f7d00280>

# %% [markdown]
# * Still overfit will try to change min_samples_leaf

# %%
rf = get_metrics(X_train_scaled,y_train,X_val_scaled,y_val,RandomForestClassifier(random_state=0,max_depth=46,min_samples_leaf=8),'rf')
# Out:
# rf train score: 0.828
# rf test score: 0.808
#               precision    recall  f1-score   support
#
#            0       0.84      0.76      0.80      2964
#            1       0.78      0.86      0.82      2964
#
#     accuracy                           0.81      5928
#    macro avg       0.81      0.81      0.81      5928
# weighted avg       0.81      0.81      0.81      5928
#
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x7fb0f7a24190>

# %% [markdown]
# * **Plot the feature importance**

# %%
(pd.Series(rf.feature_importances_, index=X.columns)
   .nlargest(20)
   .plot(kind='barh')).invert_yaxis()

# %%
model_names = ["lr","nb","knn", "svc", "rf"]

model_vars = [eval(n) for n in model_names]
model_list = list(zip(model_names, model_vars))

# %%
for model_name in model_names:
    curr_model = eval(model_name)
    print(f'{model_name} score: {curr_model.score(X_val_scaled, y_val)}')
# Out:
# lr score: 0.7972334682860999
# nb score: 0.5615721997300944
# knn score: 0.8060053981106613
# svc score: 0.8168016194331984
# rf score: 0.8075236167341431

# %%
decision_voting = voting_classifier(model_list,'hard')
# Out:
# Voting classifier val score: 0.821
#               precision    recall  f1-score   support
#
#            0       0.87      0.76      0.81      2964
#            1       0.78      0.88      0.83      2964
#
#     accuracy                           0.82      5928
#    macro avg       0.83      0.82      0.82      5928
# weighted avg       0.83      0.82      0.82      5928
#
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x7fb0f66d8b50>

# %%
avg_voting = voting_classifier(model_list,'soft')
# Out:
# Voting classifier val score: 0.811
#               precision    recall  f1-score   support
#
#            0       0.79      0.84      0.82      2964
#            1       0.83      0.78      0.81      2964
#
#     accuracy                           0.81      5928
#    macro avg       0.81      0.81      0.81      5928
# weighted avg       0.81      0.81      0.81      5928
#
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x7fb0f66cab50>

# %% [markdown]
# ## XGBoost

# %%
gbm = xgb.XGBClassifier( 
                        n_estimators=10000,
                        max_depth=4,
                        objective='binary:logistic', 
                        learning_rate=.05, 
                        subsample=.8,
                        min_child_weight=3,
                        colsample_bytree=.8
                       )

eval_set=[(X_train,y_train),(X_val,y_val)]
fit_model = gbm.fit( 
                    X_train, y_train, 
                    eval_set=eval_set,
                    eval_metric='auc', 
                    early_stopping_rounds=50,
                    verbose=False
                   )
print('XGBoost train score: {:.3f}'.format(accuracy_score(y_train, gbm.predict(X_train, ntree_limit=gbm.best_ntree_limit))))
print('XGBoost val score: {:.3f}'.format(accuracy_score(y_val, gbm.predict(X_val, ntree_limit=gbm.best_ntree_limit))))
print(classification_report(y_val, gbm.predict(X_val, ntree_limit=gbm.best_ntree_limit)))
# Out:
# XGBoost train score: 0.847
# XGBoost val score: 0.822
#               precision    recall  f1-score   support
#
#            0       0.86      0.77      0.81      2964
#            1       0.79      0.87      0.83      2964
#
#     accuracy                           0.82      5928
#    macro avg       0.83      0.82      0.82      5928
# weighted avg       0.83      0.82      0.82      5928

# %% [markdown]
# ## Plot ROC

# %%
fpr_knn, tpr_knn, thresholds_knn = roc_curve(y_val, knn.predict_proba(X_val_scaled)[:,1])
fpr_log, tpr_log, thresholds_log = roc_curve(y_val, lr.predict_proba(X_val_scaled)[:,1])
fpr_nb, tpr_nb, thresholds_nb = roc_curve(y_val, nb.predict_proba(X_val_scaled)[:,1])
fpr_rf, tpr_rf, thresholds_rf = roc_curve(y_val, rf.predict_proba(X_val)[:,1])
fpr_svc, tpr_svc, thresholds_svc = roc_curve(y_val, svc.predict_proba(X_val_scaled)[:,1])
fpr_dt, tpr_dt, thresholds_dt = roc_curve(y_val, dt.predict_proba(X_val)[:,1])
fpr_vc,tpr_vc,thresholds_vc = roc_curve(y_val, avg_voting.predict_proba(X_val_scaled)[:,1])
fpr_gbm,tpr_gbm,thresholds_gbm = roc_curve(y_val, gbm.predict_proba(X_val)[:,1])

# %%
plt.plot(fpr_knn, tpr_knn,lw=2)
plt.plot(fpr_log, tpr_log,lw=2)
plt.plot(fpr_nb, tpr_nb,lw=2)
plt.plot(fpr_rf, tpr_rf,lw=2)
plt.plot(fpr_svc, tpr_svc,lw=2)
plt.plot(fpr_dt, tpr_dt,lw=2)
plt.plot(fpr_vc, tpr_vc,lw=2)
plt.plot(fpr_gbm, tpr_gbm,lw=2)
plt.plot([0,1],[0,1],c='violet',ls='--')
plt.xlim([-0.05,1.05])
plt.ylim([-0.05,1.05])
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC Scores', fontweight='bold', fontsize=20);
plt.legend(['KNN', 'Logit', 'Naive Bayes', 'Random Forest','SVC', 'Decision Tree','Voting Classifier','XGBoost'])
print('KNN ROC AUC score = ', roc_auc_score(y_val, knn.predict_proba(X_val_scaled)[:,1]))
print('Logit ROC AUC score = ', roc_auc_score(y_val, lr.predict_proba(X_val_scaled)[:,1]))
print('Naive Bayes ROC AUC score = ', roc_auc_score(y_val, nb.predict_proba(X_val_scaled)[:,1]))
print('Random Forest ROC AUC score = ', roc_auc_score(y_val, rf.predict_proba(X_val_scaled)[:,1]))
print('Support Vector Machines ROC AUC score = ', roc_auc_score(y_val, svc.predict_proba(X_val_scaled)[:,1]))
print('Decision Tree ROC AUC score = ', roc_auc_score(y_val, dt.predict_proba(X_val_scaled)[:,1]))
print('Voting Classifier ROC AUC score = ', roc_auc_score(y_val, avg_voting.predict_proba(X_val_scaled)[:,1]))
print('XgBoost ROC AUC score = ', roc_auc_score(y_val, gbm.predict_proba(X_val)[:,1]))
# Out:
# KNN ROC AUC score =  0.8809882444484511
# Logit ROC AUC score =  0.8734870743114403
# Naive Bayes ROC AUC score =  0.8659912540226307
# Random Forest ROC AUC score =  0.8807722016423807
# Support Vector Machines ROC AUC score =  0.8820643607227349
# Decision Tree ROC AUC score =  0.7500045530622986
# Voting Classifier ROC AUC score =  0.8981479394661261

# %% [markdown]
# #### Top models in consideration
# * Voting Classifier w/ soft voting
# * XGBoost
# * Random Forest

# %% [markdown]
# * XGBoost gave me the best overall score of 0.829 and an ROC of 0.892
# * Voting classifier has a lower score at 0.813 and an ROC-AUC of 0.892 but it has better recall than XGBoost when it comes to predicting if a 'Flop' is really a 'Flop'
# * Random Forest gave me a good score of 0.816 and an ROC AUC of 0.885 I can also verify feature importance using Random Forest and it run my models relatively fast but its recall for flops is 0.76 which mean nearly 25% of flops are being classified as hits as compared to the voting classifier

# %%
fpr_rf, tpr_rf, thresholds_rf = roc_curve(y_val, rf.predict_proba(X_val)[:,1])
fpr_vc,tpr_vc,thresholds_vc = roc_curve(y_val, avg_voting.predict_proba(X_val_scaled)[:,1])
fpr_gbm,tpr_gbm,thresholds_gbm = roc_curve(y_val, gbm.predict_proba(X_val)[:,1])

# %%
plt.plot(fpr_rf, tpr_rf,lw=2)
plt.plot(fpr_vc, tpr_vc,lw=2)
plt.plot(fpr_gbm, tpr_gbm,lw=2)
plt.plot([0,1],[0,1],c='violet',ls='--')
plt.xlim([-0.05,1.05])
plt.ylim([-0.05,1.05])
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC Scores', fontweight='bold', fontsize=20);
plt.legend(['Random Forest','Voting Classifier','XGBoost'])
print('Random Forest ROC AUC score = ', roc_auc_score(y_val, rf.predict_proba(X_val_scaled)[:,1]))
print('Voting Classifier ROC AUC score = ', roc_auc_score(y_val, avg_voting.predict_proba(X_val_scaled)[:,1]))
print('XgBoost ROC AUC score = ', roc_auc_score(y_val, gbm.predict_proba(X_val)[:,1]))
# Out:
# Random Forest ROC AUC score =  0.8807722016423807
# Voting Classifier ROC AUC score =  0.8981479394661261
# XgBoost ROC AUC score =  0.8916199863954499

# %% [markdown]
# ## Final Model
# * After deciding that recall for the negative class is what I wanted to focus on and seeing the ROC of the voting classifier method. The voting classifier with 'soft' voting is my final decision model

# %%
y_pred = avg_voting.predict(X_test_scaled)
print('Voting classifier test score: {:.3f}'.format(accuracy_score(y_test, y_pred)))
# Out:
# Voting classifier test score: 0.802

# %% [markdown]
# * **Pickling the final model to run in my flask app**

# %%
filename = 'finalized_model.sav'
pickle.dump(avg_voting, open(filename, 'wb'))
